# %% [markdown]
# # Whats app analysis

# %%
import pandas as pd
import numpy as np
import re
import dateparser
from collections import Counter
import matplotlib.pyplot as plt
plt.style.use('ggplot') 

def read_file(file):
    '''Reads Whatsapp text file into a list of strings''' 

    x = open(file,'r', encoding = 'utf-8') #Opens the text file into variable x but the variable cannot be explored yet
    y = x.read() #By now it becomes a huge chunk of string that we need to separate line by line
    content = y.splitlines() #The splitline method converts the chunk of string into a list of strings
    return content

chat = read_file('Sachin Sonavane.txt')
print(len(chat))


join = [line for line in chat if  "joined using this" in line]


chat
# Out:
# 9946
# ['8/10/18, 11:17 - Messages to this chat and calls are now secured with end-to-end encryption. Tap for more info.',
#  '8/12/18, 20:15 - @mahesh23_s: <Media omitted>',
#  '8/12/18, 20:15 - @mahesh23_s: Accenture madhe Astana',
#  '8/13/18, 01:12 - @mahesh23_s: send me',
#  '8/13/18, 01:12 - @mahesh23_s: manisha',
#  '8/13/18, 01:12 - @mahesh23_s: kundlai',
#  '8/13/18, 09:15 - Sachin Sonavane: <Media omitted>',
#  '8/13/18, 09:16 - Sachin Sonavane: <Media omitted>',
#  '8/13/18, 09:24 - @mahesh23_s: thnx',
#  '8/13/18, 12:31 - @mahesh23_s: pls pay 7lack',
#  '8/13/18, 12:31 - @mahesh23_s: as prepayment',
#  '8/13/18, 12:31 - @mahesh23_s: at earliest',
#  '8/13/18, 12:31 - Sachin Sonavane: Aaj karu ka',
#  '8/13/18, 12:32 - @mahesh23_s: yes',
#  '8/13/18, 12:32 - @mahesh23_s: kar',
#  '8/13/18, 12:32 - Sachin Sonavane: Ok',
#  '8/13/18, 12:32 - @mahesh23_s: ani kiti',
#  '8/13/18, 12:32 - @mahesh23_s: mahine',
#  '8/13/18, 12:32 - @mahesh23_s: rahatata',
#  '8/13/18, 12:32 - @mahesh23_s: te vichar',
#  '8/13/18, 12:33 - Sachin Sonavane: Ha',
#  '8/13/18, 12:33 - Sachin Sonavane: Sangtat te',
#  '8/13/18, 12:33 - @mahesh23_s: ok',
#  '8/13/18, 12:33 - @mahesh23_s: cool',
#  '8/13/18, 12:34 - Sachin Sonavane: 7 lack +day interest',
#  '8/13/18, 12:34 - @mahesh23_s: yes',
#  '8/13/18, 12:34 - @mahesh23_s: deun tak',
#  '8/13/18, 12:34 - Sachin Sonavane: Ok',
#  '8/13/18, 12:58 - Sachin Sonavane: Hdfc cheque na',
#  '8/13/18, 12:58 - @mahesh23_s: yes',
#  '8/13/18, 12:58 - Sachin Sonavane: Ok',
#  '8/13/18, 12:59 - @mahesh23_s: kar aaj .. je hota te hou de',
#  '8/13/18, 12:59 - @mahesh23_s: ani te interest deto na aata',
#  '8/13/18, 12:59 - @mahesh23_s: tar tyacha fayda last madhe kasa hota te samjun ghe jamala tar',
#  '8/13/18, 13:02 - Sachin Sonavane: Ok',
#  '8/13/18, 15:55 - Sachin Sonavane: <Media omitted>',
#  '8/13/18, 16:03 - @mahesh23_s: 🙏🏻😃😃',
#  '8/13/18, 16:04 - Sachin Sonavane: <Media omitted>',
#  '8/13/18, 16:06 - Sachin Sonavane: <Media omitted>',
#  '8/13/18, 16:06 - Sachin Sonavane: He kharab zal',
#  '8/13/18, 16:07 - @mahesh23_s: tear it',
#  '8/13/18, 16:10 - Sachin Sonavane: Ha cross kelo',
#  '8/13/18, 16:12 - @mahesh23_s: ok',
#  '8/13/18, 16:25 - Sachin Sonavane: Hi',
#  '8/13/18, 16:25 - Sachin Sonavane: Call karto ka',
#  '8/13/18, 16:26 - @mahesh23_s: y',
#  '8/13/18, 16:26 - @mahesh23_s: ?',
#  '8/13/18, 16:26 - @mahesh23_s: anything urgent',
#  '8/13/18, 16:26 - @mahesh23_s: ?',
#  '8/13/18, 16:26 - Sachin Sonavane: Ho',
#  '8/13/18, 16:28 - Sachin Sonavane: Hya check made hdfc bank kelo te boltat ki hdfc ltd ch check dya mhan',
#  '8/13/18, 16:28 - @mahesh23_s: yes',
#  '8/13/18, 16:28 - @mahesh23_s: mag ?',
#  '8/13/18, 16:29 - @mahesh23_s: navin cheque nahiyr',
#  '8/13/18, 16:29 - @mahesh23_s: ka ?',
#  '8/13/18, 16:29 - Sachin Sonavane: Ahe',
#  '8/13/18, 16:29 - @mahesh23_s: mag toh vapas ghe',
#  '8/13/18, 16:29 - Sachin Sonavane: Ok',
#  '8/13/18, 16:30 - @mahesh23_s: kivha correction kar and sign kar manav',
#  '8/13/18, 16:30 - Sachin Sonavane: Cheque kharab zalyavar charge lagat nhi ka?',
#  '8/13/18, 16:30 - @mahesh23_s: nahi',
#  '8/13/18, 16:30 - @mahesh23_s: pan dar veles',
#  '8/13/18, 16:30 - @mahesh23_s: karto',
#  '8/13/18, 16:30 - @mahesh23_s: tula mahiti nahi ka ?',
#  '8/13/18, 16:31 - Sachin Sonavane: Gelyaveles hdfc ltd mention kelo',
#  '8/13/18, 16:31 - Sachin Sonavane: Teva tith Sir hota',
#  '8/13/18, 16:31 - Sachin Sonavane: Atta madam ahe',
#  '8/13/18, 16:32 - @mahesh23_s: ok',
#  '8/13/18, 16:32 - @mahesh23_s: no problem',
#  '8/13/18, 16:32 - Sachin Sonavane: Sir bolala ki hdfc bank/hdfc ltd ok mhanala',
#  '8/13/18, 16:32 - @mahesh23_s: toh cheque ghe and fadun tak',
#  '8/13/18, 16:32 - @mahesh23_s: navin cheque de tyana',
#  '8/13/18, 16:32 - Sachin Sonavane: Ok',
#  '8/13/18, 16:32 - @mahesh23_s: he navin detil tula',
#  '8/13/18, 16:32 - Sachin Sonavane: Previous cheque ahe majya kade',
#  '8/13/18, 16:33 - @mahesh23_s: okk',
#  '8/13/18, 16:33 - @mahesh23_s: problem kay ahe mag?',
#  '8/13/18, 16:33 - Sachin Sonavane: <Media omitted>',
#  '8/13/18, 16:33 - @mahesh23_s: sachin kay bolto te samjahat',
#  '8/13/18, 16:33 - @mahesh23_s: nahi mala',
#  '8/13/18, 16:33 - Sachin Sonavane: Kahi nhi new cheque deun ja mhan',
#  '8/13/18, 16:34 - @mahesh23_s: asa confuse nako hot jau',
#  '8/13/18, 16:34 - @mahesh23_s: ani karat jaaus',
#  '8/13/18, 16:34 - @mahesh23_s: normal prepayment karun ye',
#  '8/13/18, 16:34 - Sachin Sonavane: Ok',
#  '8/13/18, 16:34 - @mahesh23_s: hya document varti cheque number barobar ahe ki nahi ge bag .. nasel tar navin ghe',
#  '8/13/18, 17:03 - Sachin Sonavane: <Media omitted>',
#  '8/13/18, 17:05 - @mahesh23_s: ok',
#  '8/13/18, 17:05 - Sachin Sonavane: Dilo cheque Singh  thodi cross ali chalel na pass hoto na atta',
#  '8/13/18, 17:05 - @mahesh23_s: yes',
#  '8/13/18, 17:05 - @mahesh23_s: dont worry too much',
#  '8/13/18, 17:05 - @mahesh23_s: its normal process',
#  '8/13/18, 17:05 - @mahesh23_s: he dila ka ?',
#  '8/13/18, 17:05 - @mahesh23_s: updated copy ?',
#  '8/13/18, 17:06 - Sachin Sonavane: Nhi tyat correction karun dila',
#  '8/13/18, 17:06 - @mahesh23_s: chalata na vichar',
#  '8/13/18, 17:06 - @mahesh23_s: tyala',
#  '8/13/18, 17:06 - Sachin Sonavane: Cheque ade correction nhi chalat mhan tyana',
#  '8/13/18, 17:06 - @mahesh23_s: ok',
#  '8/13/18, 17:06 - @mahesh23_s: samjala',
#  '8/13/18, 17:06 - @mahesh23_s: jaaude mag',
#  '8/13/18, 17:06 - @mahesh23_s: ye ghari',
#  '8/13/18, 17:06 - @mahesh23_s: correction kelela screenshot pathav bagu',
#  '8/13/18, 17:06 - Sachin Sonavane: Ok',
#  '8/13/18, 17:07 - Sachin Sonavane: <Media omitted>',
#  '8/13/18, 17:08 - Sachin Sonavane: <Media omitted>',
#  '8/13/18, 17:11 - @mahesh23_s: ok',
#  '8/13/18, 17:11 - @mahesh23_s: sign kar manav',
#  '8/13/18, 17:11 - @mahesh23_s: tyaka',
#  '8/13/18, 17:12 - @mahesh23_s: tithe',
#  '8/13/18, 17:12 - @mahesh23_s: nahi tar jaaude',
#  '8/13/18, 17:12 - @mahesh23_s: ye ghari',
#  '8/13/18, 17:28 - Sachin Sonavane: 😃',
#  '8/13/18, 17:28 - @mahesh23_s: aata',
#  '8/13/18, 17:29 - @mahesh23_s: 2039636',
#  '8/13/18, 17:29 - @mahesh23_s: yevadhe',
#  '8/13/18, 17:29 - @mahesh23_s: rahile',
#  '8/13/18, 17:29 - @mahesh23_s: ?',
#  '8/13/18, 17:29 - @mahesh23_s: 89 months',
#  '8/13/18, 17:29 - @mahesh23_s: ?',
#  '8/13/18, 17:29 - @mahesh23_s: sadesath varsha',
#  '8/13/18, 17:29 - @mahesh23_s: rahile vatata',
#  '8/13/18, 17:31 - Sachin Sonavane: Ho',
#  '8/13/18, 17:31 - @mahesh23_s: nice',
#  '8/13/18, 17:31 - @mahesh23_s: from 360 to 89 😍😍😍',
#  '8/13/18, 17:31 - @mahesh23_s: jabardast',
#  '8/13/18, 17:31 - Sachin Sonavane: ☺👌🏻👍🏻',
#  '8/13/18, 17:32 - @mahesh23_s: ajun ek varshat',
#  '8/13/18, 17:32 - @mahesh23_s: nipatun taku',
#  '8/13/18, 17:32 - Sachin Sonavane: Te bolale ki Oct 1 la interest may be vadhel mhan',
#  '8/13/18, 17:32 - @mahesh23_s: jar job rahila tar',
#  '8/13/18, 17:32 - @mahesh23_s: ok',
#  '8/13/18, 17:32 - Sachin Sonavane: 9%',
#  '8/13/18, 17:32 - @mahesh23_s: kiti vadel man',
#  '8/13/18, 17:32 - @mahesh23_s: theek she',
#  '8/13/18, 17:32 - @mahesh23_s: ahe',
#  '8/13/18, 17:33 - Sachin Sonavane: Mg tumhi 8.7 % kara mhan',
#  '8/13/18, 18:23 - @mahesh23_s: manje',
#  '8/13/18, 18:23 - @mahesh23_s: ?',
#  '8/13/18, 18:24 - Sachin Sonavane: This message was deleted',
#  '8/13/18, 18:25 - Sachin Sonavane: This message was deleted',
#  '8/13/18, 18:25 - @mahesh23_s: ok',
#  '8/13/18, 18:25 - @mahesh23_s: kiti charge',
#  '8/13/18, 18:25 - @mahesh23_s: karava lagel',
#  '8/13/18, 18:25 - @mahesh23_s: ?',
#  '8/13/18, 18:27 - Sachin Sonavane: Part payment kelo na 2    divas lagtat update vayla so charge sadya tari nhi sangitle',
#  '8/13/18, 18:28 - Sachin Sonavane: Online customer la call kel ki te pn rate down karun detat mhan',
#  '8/13/18, 18:28 - Sachin Sonavane: Charge online link patavtat mhan',
#  '8/13/18, 18:28 - Sachin Sonavane: Thik ahe bolalo',
#  '8/13/18, 18:29 - @mahesh23_s: ok',
#  '8/13/18, 18:29 - @mahesh23_s: fine',
#  '8/13/18, 18:29 - Sachin Sonavane: Oct made bagu mhanalo',
#  '8/13/18, 18:54 - @mahesh23_s: bar',
#  '8/13/18, 19:06 - Sachin Sonavane: We appreciate your loyalty towards HDFC Life Policy No. 19243197. Premium of INR 5000 is due on 18/08/18. To pay online, click goo.gl/FQL71D. T&C apply.',
#  '8/13/18, 19:06 - @mahesh23_s: ok',
#  '8/13/18, 22:57 - @mahesh23_s: <Media omitted>',
#  '8/13/18, 22:57 - Sachin Sonavane: Ha kar',
#  '8/13/18, 22:59 - Sachin Sonavane: Audio clear nhi',
#  '8/13/18, 23:19 - @mahesh23_s: <Media omitted>',
#  '8/13/18, 23:22 - Sachin Sonavane: <Media omitted>',
#  '8/13/18, 23:40 - @mahesh23_s: Her Rashi is Mesh and star is Ashwini .... What they told is vorrect',
#  '8/13/18, 23:40 - @mahesh23_s: Adi naadi for both',
#  '8/13/18, 23:44 - Sachin Sonavane: Aai la mahitiy ',
#  'Aaj *Nana Ghari alela* to pn manala dogach half half Nadi ahe .',
#  '',
#  'Atta bagu aai ajun ekada pachang kadun v4ti mhan',
#  '8/13/18, 23:45 - @mahesh23_s: ok',
#  '8/14/18, 09:02 - @mahesh23_s: <Media omitted>',
#  '8/14/18, 09:02 - @mahesh23_s: <Media omitted>',
#  '8/14/18, 09:02 - @mahesh23_s: <Media omitted>',
#  '8/14/18, 09:02 - @mahesh23_s: gm',
#  '8/14/18, 09:02 - Sachin Sonavane: Gm',
#  '8/14/18, 09:03 - @mahesh23_s: fresh hoto ahe',
#  '8/14/18, 09:03 - Sachin Sonavane: Call karnar ahe',
#  '8/14/18, 09:03 - Sachin Sonavane: Ok',
#  '8/14/18, 09:03 - @mahesh23_s: nahi',
#  '8/14/18, 09:03 - @mahesh23_s: karan office la jayachay',
#  '8/14/18, 09:04 - Sachin Sonavane: Hi fresh',
#  '8/14/18, 09:04 - Sachin Sonavane: Ho*',
#  '8/14/18, 18:16 - Sachin Sonavane: UPDATE: INR 7,02,026.00 has been debited from your A/c XX6291 towards Cheque No. 000006. Clearing Date: 14-AUG-18. Available balance: INR 35,996.10',
#  '8/14/18, 18:17 - Sachin Sonavane: Consequent to revision in the HDFC-RPLR with effect from August 1, 2018, your applicable interest rate under ARHL scheme has been increased by 20 basis points (bps) with effect from your interest reset date. In case of any further assistance, please contact the nearest HDFC office.',
#  '8/14/18, 18:34 - @mahesh23_s: ok',
#  '8/14/18, 18:34 - @mahesh23_s: otp yeil santo ka ?',
#  '8/14/18, 19:40 - Sachin Sonavane: Ok',
#  '8/14/18, 21:30 - Sachin Sonavane: Dear Sir / Madam, An email communication sent to your email id mahesh.sonavane14@hotmail.com has returned undelivered. Please confirm your email id with a reply to 56767, from your registered mobile number, in the format HDFCBM<SPACE><HDFC LOAN ACCOUNT NO><SPACE><EMAILID>.',
#  '',
#  'E.g. HDFCBM 123456789 abc@xyz.com',
#  '8/14/18, 22:13 - @mahesh23_s: Kay karat',
#  '8/14/18, 22:13 - @mahesh23_s: hota ka ?',
#  '8/14/18, 22:13 - @mahesh23_s: hdfc varti',
#  '8/14/18, 22:13 - @mahesh23_s: ?',
#  '8/14/18, 22:14 - Sachin Sonavane: Nhi',
#  '8/14/18, 22:14 - @mahesh23_s: ok',
#  '8/14/18, 22:14 - @mahesh23_s: bagto',
#  '8/14/18, 22:14 - @mahesh23_s: thamb',
#  '8/15/18, 10:11 - @mahesh23_s: hi',
#  '8/15/18, 10:11 - @mahesh23_s: otp yeil',
#  '8/15/18, 10:11 - @mahesh23_s: sangto',
#  '8/15/18, 10:11 - @mahesh23_s: ka ?',
#  '8/15/18, 10:47 - Sachin Sonavane: Hi',
#  '8/15/18, 10:47 - Sachin Sonavane: Sang to',
#  '8/15/18, 10:47 - @mahesh23_s: ok',
#  '8/15/18, 21:55 - Sachin Sonavane: 183402',
#  '8/15/18, 22:01 - Sachin Sonavane: <Media omitted>',
#  '8/15/18, 22:16 - Sachin Sonavane: Payment dtd 09:59 PM IST on Aug 15,2018 for HDFC Life Policy 19243197 is in process.Status will be updated in 48 hrs.For details,mail service@hdfclife.com',
#  '8/16/18, 13:50 - @mahesh23_s: hi',
#  '8/16/18, 13:50 - @mahesh23_s: otp',
#  '8/16/18, 13:50 - @mahesh23_s: yeil',
#  '8/16/18, 13:50 - @mahesh23_s: sangto',
#  '8/16/18, 13:50 - @mahesh23_s: ka',
#  '8/16/18, 13:50 - @mahesh23_s: ??',
#  '8/16/18, 13:50 - @mahesh23_s: ki jopla',
#  '8/16/18, 13:50 - @mahesh23_s: ahe',
#  '8/16/18, 13:50 - @mahesh23_s: ?',
#  '8/16/18, 14:10 - Sachin Sonavane: Sangto',
#  '8/16/18, 14:12 - @mahesh23_s: sang',
#  '8/16/18, 14:12 - @mahesh23_s: mag',
#  '8/16/18, 14:12 - @mahesh23_s: alaa ka ?',
#  '8/16/18, 14:12 - Sachin Sonavane: Nhi',
#  '8/16/18, 14:12 - @mahesh23_s: ok yeil',
#  '8/16/18, 14:35 - @mahesh23_s: nahi yenaar',
#  '8/16/18, 14:36 - Sachin Sonavane: Ok',
#  '8/16/18, 14:36 - Sachin Sonavane: Problem ahe ka server la',
#  '8/16/18, 14:37 - @mahesh23_s: yes',
#  '8/16/18, 14:38 - Sachin Sonavane: 😒18 August due date ahe',
#  '8/16/18, 14:38 - @mahesh23_s: yes',
#  '8/16/18, 14:38 - @mahesh23_s: bagu',
#  '8/16/18, 14:38 - @mahesh23_s: udya',
#  '8/16/18, 14:39 - Sachin Sonavane: Ok',
#  '8/16/18, 22:07 - Sachin Sonavane: Hi',
#  '8/16/18, 22:07 - Sachin Sonavane: Labmade Ahe',
#  '8/16/18, 22:08 - @mahesh23_s: ok',
#  '8/16/18, 22:08 - Sachin Sonavane: 10:30 la kar',
#  '8/16/18, 23:19 - @mahesh23_s: https://myaccount.hdfclife.com/',
#  '8/16/18, 23:19 - @mahesh23_s: mahesh.sonavane14@hotmail.com',
#  '8/16/18, 23:20 - @mahesh23_s: mms28@Hdfclife',
#  '8/16/18, 23:30 - Sachin Sonavane: <Media omitted>',
#  '8/16/18, 23:32 - Sachin Sonavane: Premium payment of INR 5000.0 dtd Aug 16,2018 at 11:29 PM  for HDFC Life policy 19243197 was successful. For details, email service@hdfclife.com',
#  '8/16/18, 23:32 - Sachin Sonavane: Rs.5000.00 was spent on ur HDFCBank CREDIT Card ending 8078 on 2018-08-16:23:30:02 at HDFCLIFE1187434.Avl bal - Rs.133165.28, curr o/s - Rs.16834.72',
#  '8/16/18, 23:33 - Sachin Sonavane: Pan card number nhi taklo',
#  '8/16/18, 23:50 - @mahesh23_s: superb',
#  '8/16/18, 23:51 - @mahesh23_s: 😃😃',
#  '8/16/18, 23:51 - Sachin Sonavane: Ha',
#  '8/16/18, 23:52 - Sachin Sonavane: I think payment gateway background la  location  check kartay vatatay',
#  '8/17/18, 00:14 - @mahesh23_s: ohh oj',
#  '8/17/18, 00:14 - @mahesh23_s: tu karat ja mag',
#  '8/17/18, 00:14 - @mahesh23_s: payment hyapudhe',
#  '8/17/18, 00:15 - Sachin Sonavane: Ok',
#  '8/17/18, 00:15 - @mahesh23_s: yar tya mulila kasa sangu',
#  '8/17/18, 00:15 - @mahesh23_s: ?',
#  '8/17/18, 00:15 - Sachin Sonavane: Reminder det ja☺',
#  '8/17/18, 00:15 - @mahesh23_s: nahi honar nahi manun',
#  '8/17/18, 00:15 - @mahesh23_s: lagn',
#  '8/17/18, 00:17 - Sachin Sonavane: Tula karaych asel tr ek option ahe te pn swamila vi4rv lagel',
#  '8/17/18, 00:17 - @mahesh23_s: ok..',
#  '8/17/18, 00:17 - Sachin Sonavane: Nasel tr mi aai la sangto udya',
#  '8/17/18, 00:17 - Sachin Sonavane: Call',
#  '8/17/18, 00:17 - Sachin Sonavane: Karun tyanchya vadila',
#  '8/17/18, 00:18 - Sachin Sonavane: La',
#  '8/17/18, 00:18 - @mahesh23_s: ok..',
#  '8/17/18, 00:18 - @mahesh23_s: jaaude bhanu pan nako bolat ahe',
#  '8/17/18, 00:19 - @mahesh23_s: sagle nako bolat ahet.. negativity jast ahe',
#  '8/17/18, 00:19 - @mahesh23_s: sang manav aaila',
#  '8/17/18, 00:19 - @mahesh23_s: np',
#  '8/17/18, 00:20 - Sachin Sonavane: Tya swamich number deto Bolto ka tu',
#  '8/17/18, 00:21 - Sachin Sonavane: Mi massage Karu ka Tila ki kundli julat nhi mhanun',
#  '8/17/18, 00:31 - @mahesh23_s: ok..de number mi bolto swami la ekda',
#  '8/17/18, 00:31 - @mahesh23_s: nako. mi bolto',
#  '8/17/18, 13:09 - Sachin Sonavane: Hi',
#  '8/17/18, 13:09 - @mahesh23_s: hi',
#  '8/17/18, 16:16 - Sachin Sonavane: Hi',
#  '8/17/18, 16:16 - Sachin Sonavane: Missed video call',
#  '8/17/18, 16:19 - Sachin Sonavane: Aai la call kar',
#  '8/17/18, 16:28 - @mahesh23_s: kela',
#  '8/18/18, 09:57 - Sachin Sonavane: Dear Customer, E-stmt for HDFCBank CreditCard 8078 will be sent to your Email ID. Min Due Rs.1048 Total Due Rs.12221. Payment due by 06/SEP/2018.',
#  '8/18/18, 13:13 - Sachin Sonavane: This message was deleted',
#  '8/18/18, 13:35 - @mahesh23_s: kay',
#  '8/18/18, 13:35 - @mahesh23_s: jala re',
#  '8/18/18, 20:04 - Sachin Sonavane: 9822774775',
#  'Gajanan guruji',
#  '8/18/18, 20:04 - @mahesh23_s: ok',
#  '8/18/18, 20:04 - Sachin Sonavane: Hyderabad la rahto bol tu',
#  '8/18/18, 20:04 - @mahesh23_s: 9822774775',
#  '8/18/18, 20:04 - @mahesh23_s: ok',
#  '8/18/18, 20:07 - Sachin Sonavane: Tyala dogach bod & time sang  to details sangel or aai and bro alele kundli julat nhi mhanun sangitla and option sathi kay tr sangnar hota ',
#  '',
#  'Kel tr changl ahe ka v4......',
#  '8/18/18, 20:08 - @mahesh23_s: ok',
#  '8/19/18, 21:19 - @mahesh23_s: 🚴🏼\u200d♂🏃🏻\u200d♂😇🤲🏻',
#  '8/19/18, 22:38 - Sachin Sonavane: Mobile la charging samplay',
#  '8/19/18, 22:38 - Sachin Sonavane: Nantr karto',
#  '8/19/18, 22:38 - Sachin Sonavane: Emergency ahe ka',
#  '8/19/18, 22:42 - @mahesh23_s: ok',
#  '8/19/18, 22:42 - @mahesh23_s: nahi',
#  '8/19/18, 22:42 - @mahesh23_s: aai cha phone ?',
#  '8/20/18, 14:58 - @mahesh23_s: hi',
#  '8/20/18, 14:58 - @mahesh23_s: aaila kamala ka pathvla ?',
#  '8/20/18, 14:58 - @mahesh23_s: kothe chalali ti kamala ?',
#  '8/20/18, 18:50 - Sachin Sonavane: Hi',
#  '8/20/18, 20:21 - Sachin Sonavane: Ami aju. Ekada tya swami kade aloy',
#  '8/20/18, 20:21 - Sachin Sonavane: Parat v4rayla',
#  '8/20/18, 20:21 - Sachin Sonavane: Tu call kelela ka tyanhw',
#  '8/20/18, 20:22 - Sachin Sonavane: Tyanha*',
#  '8/20/18, 20:27 - @mahesh23_s: yes',
#  '8/20/18, 20:27 - @mahesh23_s: uchala nahu',
#  '8/20/18, 20:28 - @mahesh23_s: tyani',
#  '8/20/18, 20:28 - @mahesh23_s: ok vichar ani sang',
#  '8/20/18, 20:28 - Sachin Sonavane: Ok',
#  '8/20/18, 20:28 - @mahesh23_s: aani aai kahi tri sangnaar',
#  '8/20/18, 20:28 - @mahesh23_s: hoti',
#  '8/20/18, 20:28 - @mahesh23_s: kay mana ?',
#  '8/20/18, 20:28 - @mahesh23_s: vichar tila',
#  '8/20/18, 20:28 - Sachin Sonavane: Tyana Bolto ka',
#  '8/20/18, 20:29 - Sachin Sonavane: Amhi aju. Ethech ahe',
#  '8/20/18, 20:29 - Sachin Sonavane: Ajun v4l nhi',
#  '8/20/18, 20:29 - Sachin Sonavane: Line ahe ethe',
#  '8/20/18, 20:29 - Sachin Sonavane: Tu bolnar asel tr WhatsApp call karto thodya velen',
#  '8/20/18, 20:29 - @mahesh23_s: nako',
#  '8/20/18, 20:29 - @mahesh23_s: baher alo',
#  '8/20/18, 20:30 - @mahesh23_s: udya karto',
#  '8/20/18, 20:30 - Sachin Sonavane: Achya',
#  '8/20/18, 20:30 - @mahesh23_s: ok tyana clearly sanga manav ..',
#  '8/20/18, 20:31 - Sachin Sonavane: Ok',
#  '8/20/18, 20:32 - Sachin Sonavane: Tu tyana bolala tr khup Bhari hoiel',
#  '8/20/18, 20:32 - Sachin Sonavane: Thod vel nhi k',
#  '8/20/18, 20:32 - Sachin Sonavane: May be 8:45 pm nantr',
#  '8/20/18, 20:33 - Sachin Sonavane: Or 9nantr',
#  '8/20/18, 20:33 - @mahesh23_s: ok.. ok',
#  '8/20/18, 20:33 - @mahesh23_s: bagu call karto mag',
#  '8/20/18, 20:33 - Sachin Sonavane: Bagu smg karto',
#  '8/20/18, 20:33 - Sachin Sonavane: Ok',
#  '8/20/18, 20:33 - @mahesh23_s: sms',
#  '8/20/18, 20:33 - @mahesh23_s: kar',
#  '8/20/18, 21:04 - Sachin Sonavane: Hi',
#  '8/20/18, 21:05 - Sachin Sonavane: Hello',
#  '8/20/18, 21:08 - Sachin Sonavane: Hi',
#  '8/20/18, 21:33 - Sachin Sonavane: Tya guruji la call kar to boltoy mhanala',
#  '8/20/18, 21:34 - Sachin Sonavane: Tya divashi tu call kela na to mhanala ki +97..** bagun to call receive kela nhi mhan',
#  '8/20/18, 21:35 - Sachin Sonavane: To mhanla WhatsApp call Kel tari chalel mhanala',
#  '8/20/18, 21:36 - Sachin Sonavane: Dubai la rahato sangitloy because number Varun olakhato na manun',
#  '8/20/18, 21:36 - Sachin Sonavane: Sandya Kali 10pm nantr call kar mhan',
#  '8/20/18, 21:37 - Sachin Sonavane: *Call kartana record Karun thev mhan *',
#  '8/20/18, 22:52 - @mahesh23_s: ok',
#  '8/20/18, 22:52 - @mahesh23_s: theek ahe',
#  '8/20/18, 22:52 - Sachin Sonavane: Atta Kel Tari chalel',
#  '8/20/18, 22:52 - Sachin Sonavane: Attach gelay to pn Ghari',
#  '8/20/18, 23:03 - @mahesh23_s: kela call',
#  '8/20/18, 23:04 - Sachin Sonavane: Achya',
#  '8/20/18, 23:04 - @mahesh23_s: call',
#  '8/20/18, 23:04 - @mahesh23_s: uchala',
#  "8/20/18, 23:05 - @mahesh23_s: what's app nahi",
#  '8/20/18, 23:05 - @mahesh23_s: honaar',
#  '8/20/18, 23:05 - Sachin Sonavane: Ok',
#  '8/20/18, 23:05 - Sachin Sonavane: Kar',
#  '8/21/18, 16:33 - Sachin Sonavane: Hi',
#  '8/21/18, 16:33 - @mahesh23_s: kay kartoy',
#  '8/21/18, 16:33 - @mahesh23_s: re',
#  '8/21/18, 16:33 - @mahesh23_s: ??',
#  '8/21/18, 16:33 - Sachin Sonavane: Lab',
#  '8/21/18, 16:34 - @mahesh23_s: ok',
#  '8/21/18, 16:34 - @mahesh23_s: kar abhyas nitant',
#  '8/21/18, 16:34 - Sachin Sonavane: Kay zal',
#  '8/21/18, 16:34 - @mahesh23_s: asach ping kelelo',
#  '8/21/18, 16:34 - @mahesh23_s: ajun kahi kon bolala ka ?',
#  '8/21/18, 16:34 - @mahesh23_s: nahi na ?',
#  '8/21/18, 16:34 - Sachin Sonavane: Nhi',
#  "8/22/18, 18:04 - @mahesh23_s: don't filter on surrogate keys.. rather create unique product id column in the product dimension which will remain constant across all  environments..",
#  '8/22/18, 18:04 - @mahesh23_s: ignore',
#  '8/23/18, 21:49 - Sachin Sonavane: Missed group video call',
#  '8/23/18, 21:51 - Sachin Sonavane: Aai la kar',
#  '8/23/18, 21:51 - Sachin Sonavane: Mi ghari jatoy',
#  '8/24/18, 14:07 - Sachin Sonavane: Lab made ahe',
#  '8/24/18, 14:07 - @mahesh23_s: ok',
#  '8/24/18, 14:07 - @mahesh23_s: kar abhyas',
#  '8/24/18, 14:07 - @mahesh23_s: mi pan karto',
#  '8/24/18, 14:07 - @mahesh23_s: abhyas',
#  '8/24/18, 14:07 - Sachin Sonavane: Ok',
#  '8/24/18, 14:07 - @mahesh23_s: nanter bolu',
#  '8/24/18, 14:08 - Sachin Sonavane: Ha',
#  '8/25/18, 04:02 - @mahesh23_s: a simple GUI application hashtag#directory_analyser_v1, written using python libraries: os, pandas, seaborn, tkinter, matplotlib and progressbar..',
#  '',
#  'Please help me adding more insights to it by mentioning your ideas..!! Stay tuned for version 2... :)',
#  '8/25/18, 15:20 - Sachin Sonavane: ??',
#  '8/25/18, 15:20 - @mahesh23_s: asach',
#  '8/25/18, 15:20 - @mahesh23_s: kelo',
#  '8/25/18, 15:20 - @mahesh23_s: kothe ahe',
#  '8/25/18, 15:20 - @mahesh23_s: ?',
#  '8/25/18, 15:20 - Sachin Sonavane: Lab',
#  '8/25/18, 15:20 - @mahesh23_s: ok',
#  '8/25/18, 15:20 - @mahesh23_s: aaila karto',
#  '8/25/18, 15:20 - Sachin Sonavane: Ha',
#  '8/25/18, 22:56 - @mahesh23_s: <Media omitted>',
#  '8/25/18, 22:56 - @mahesh23_s: <Media omitted>',
#  '8/26/18, 22:09 - Sachin Sonavane: Ok',
#  '8/28/18, 20:55 - Sachin Sonavane: http://www.sytpl.in',
#  '8/29/18, 01:49 - @mahesh23_s: go for it',
#  '8/29/18, 01:50 - @mahesh23_s: all the best bro',
#  '8/29/18, 01:50 - @mahesh23_s: work hard ..',
#  '8/29/18, 01:50 - @mahesh23_s: and always remember .. bro loves u 😍',
#  '8/29/18, 01:50 - @mahesh23_s: gn',
#  '8/29/18, 01:50 - @mahesh23_s: take cate',
#  '8/29/18, 01:51 - @mahesh23_s: care',
#  '8/29/18, 08:29 - Sachin Sonavane: ☺🌞',
#  '8/29/18, 09:18 - Sachin Sonavane: IMPORTANT! ',
#  "We are upgrading your Debit Card to a chip based card offering enhanced security. Incase you've changed your address, update it via NetBanking>Update contact details or at Branch. We'll update you with card dispatch details shortly",
#  '8/29/18, 09:18 - Sachin Sonavane: Dear Prime Customer, Cashback points earned on your HDFC Bank Debit Card in September 2017 will expire on 1st Oct 2018. Redeem before they expire. Ignore if done.',
#  '8/29/18, 09:28 - @mahesh23_s: k',
#  '8/29/18, 21:58 - @mahesh23_s: join',
#  '8/29/18, 21:58 - @mahesh23_s: zoom',
#  '8/29/18, 21:58 - Sachin Sonavane: Ok',
#  '8/29/18, 21:58 - @mahesh23_s: https://zoom.us/j/9892821748',
#  '8/30/18, 21:17 - @mahesh23_s: hi',
#  '8/30/18, 21:18 - Sachin Sonavane: Ghari',
#  '8/30/18, 21:18 - @mahesh23_s: join zoom',
#  '8/30/18, 21:18 - Sachin Sonavane: Ahe',
#  '8/30/18, 21:18 - Sachin Sonavane: Bol',
#  '8/30/18, 21:18 - @mahesh23_s: https://zoom.us/j/9892821748',
#  '9/1/18, 20:04 - Sachin Sonavane: <Media omitted>',
#  '9/1/18, 20:04 - Sachin Sonavane: Olakhata ka',
#  '9/1/18, 20:04 - Sachin Sonavane: <Media omitted>',
#  '9/1/18, 20:05 - @mahesh23_s: konalacha nahi olakhat',
#  '9/1/18, 21:21 - Sachin Sonavane: Ac no 446822',
#  'Has been debited by Rs 50000 on sep 1,2018',
#  '9/1/18, 21:27 - @mahesh23_s: yes pathavalo',
#  '9/1/18, 21:27 - @mahesh23_s: mi paise',
#  '9/1/18, 21:27 - @mahesh23_s: hdfc madhe',
#  '9/1/18, 21:27 - Sachin Sonavane: Ok👍🏻',
#  '9/1/18, 21:27 - @mahesh23_s: emi ahe ani credit card payment pan baki ahe',
#  '9/1/18, 21:27 - @mahesh23_s: manun',
#  '9/1/18, 21:27 - Sachin Sonavane: Ha',
#  '9/1/18, 21:28 - @mahesh23_s: nicr',
#  '9/1/18, 21:28 - Sachin Sonavane: HDFC bank ch call alel receive nhi kel bcz mobile (sim) Ghari hot',
#  '9/1/18, 21:29 - Sachin Sonavane: ☺',
#  '9/1/18, 21:35 - @mahesh23_s: ok no problem',
#  '9/3/18, 20:52 - Sachin Sonavane: Hi',
#  '9/3/18, 20:53 - @mahesh23_s: phone receive kara',
#  '9/3/18, 20:53 - @mahesh23_s: baher ahe mi',
#  '9/3/18, 20:53 - Sachin Sonavane: Ok',
#  '9/3/18, 20:53 - Sachin Sonavane: Kar',
#  '9/3/18, 20:54 - Sachin Sonavane: Runval society samor',
#  '9/3/18, 20:54 - Sachin Sonavane: Aloy',
#  '9/3/18, 20:54 - Sachin Sonavane: Hundi bagayla',
#  '9/3/18, 20:54 - @mahesh23_s: ok',
#  '9/3/18, 20:54 - @mahesh23_s: baga mag',
#  '9/3/18, 20:54 - @mahesh23_s: udya karto call',
#  '9/3/18, 20:55 - @mahesh23_s: aaj nahi karat',
#  '9/3/18, 20:55 - @mahesh23_s: baga ani jopa',
#  '9/3/18, 20:55 - @mahesh23_s: 👍🏻',
#  '9/3/18, 20:55 - Sachin Sonavane: Any emergency',
#  '9/3/18, 20:55 - @mahesh23_s: nope',
#  '9/3/18, 20:55 - Sachin Sonavane: Ok',
#  '9/3/18, 20:59 - Sachin Sonavane: <Media omitted>',
#  '9/3/18, 20:59 - @mahesh23_s: wah nice baga',
#  '9/3/18, 21:00 - @mahesh23_s: punyat mast asata',
#  '9/3/18, 21:00 - @mahesh23_s: enjoy .. tya deshpande',
#  '9/3/18, 21:00 - @mahesh23_s: chya gallery madhun',
#  '9/3/18, 21:00 - @mahesh23_s: pan disata asel na',
#  '9/3/18, 21:00 - Sachin Sonavane: <Media omitted>',
#  '9/3/18, 21:01 - Sachin Sonavane: No',
#  '9/3/18, 21:01 - @mahesh23_s: ok',
#  '9/3/18, 21:01 - Sachin Sonavane: <Media omitted>',
#  '9/3/18, 22:17 - @mahesh23_s: hi',
#  '9/3/18, 22:33 - Sachin Sonavane: ??',
#  '9/3/18, 22:33 - @mahesh23_s: ala',
#  '9/3/18, 22:33 - @mahesh23_s: ka ghari',
#  '9/3/18, 22:33 - @mahesh23_s: ki baher ahe',
#  '9/3/18, 22:33 - @mahesh23_s: ?',
#  '9/3/18, 22:33 - Sachin Sonavane: Baher',
#  '9/3/18, 22:33 - @mahesh23_s: ok',
#  '9/3/18, 22:33 - @mahesh23_s: njoy',
#  '9/3/18, 22:33 - @mahesh23_s: udya karto call',
#  '9/3/18, 22:33 - @mahesh23_s: :)',
#  '9/3/18, 22:34 - @mahesh23_s: no emergency',
#  '9/3/18, 22:35 - Sachin Sonavane: 5 min',
#  '9/3/18, 22:35 - Sachin Sonavane: Bol',
#  '9/3/18, 22:35 - Sachin Sonavane: Sound system band ahe',
#  '9/3/18, 22:35 - @mahesh23_s: kahi nahi',
#  '9/3/18, 22:35 - @mahesh23_s: re',
#  '9/3/18, 22:35 - @mahesh23_s: asach',
#  '9/3/18, 22:35 - @mahesh23_s: bolalo',
#  '9/3/18, 22:35 - @mahesh23_s: jaaude udya karto',
#  '9/3/18, 22:37 - Sachin Sonavane: 👍🏻ok',
#  '9/4/18, 22:32 - @mahesh23_s: hi',
#  '9/4/18, 22:33 - @mahesh23_s: zoom',
#  '9/4/18, 22:35 - @mahesh23_s: https://zoom.us/j/9892821748',
#  '9/4/18, 22:35 - @mahesh23_s: join this',
#  '9/5/18, 22:03 - @mahesh23_s: hi',
#  '9/5/18, 22:03 - @mahesh23_s: join zoom',
#  '9/5/18, 22:04 - Sachin Sonavane: Ok',
#  '9/5/18, 22:04 - @mahesh23_s: zoom',
#  '9/5/18, 22:04 - @mahesh23_s: ??',
#  '9/5/18, 22:04 - @mahesh23_s: not whats app',
#  '9/5/18, 22:04 - Sachin Sonavane: Ok',
#  '9/6/18, 12:00 - @mahesh23_s: hi',
#  '9/6/18, 12:00 - @mahesh23_s: credit',
#  '9/6/18, 12:00 - @mahesh23_s: card details',
#  '9/6/18, 12:00 - @mahesh23_s: pathav',
#  '9/6/18, 12:01 - Sachin Sonavane: 5523650000258078',
#  '9/6/18, 12:01 - Sachin Sonavane: 643',
#  '9/6/18, 12:01 - Sachin Sonavane: 05/20',
#  '9/6/18, 12:02 - @mahesh23_s: mobile gharaat',
#  '9/6/18, 12:03 - @mahesh23_s: theun ka ala',
#  '9/6/18, 12:03 - @mahesh23_s: vichitra manus ahe',
#  '9/6/18, 12:03 - @mahesh23_s: tu pan',
#  '9/6/18, 12:03 - @mahesh23_s: jevha pahije',
#  '9/6/18, 12:03 - @mahesh23_s: tevha no use',
#  '9/6/18, 12:03 - Sachin Sonavane: Sim replace kela',
#  '9/6/18, 12:04 - @mahesh23_s: ok',
#  '9/6/18, 12:04 - @mahesh23_s: no problem',
#  '9/6/18, 12:05 - @mahesh23_s: ghari gelyavar',
#  '9/6/18, 12:05 - @mahesh23_s: sagalyat',
#  '9/6/18, 12:06 - @mahesh23_s: agodsr',
#  '9/6/18, 12:06 - @mahesh23_s: ping kar',
#  '9/6/18, 12:06 - @mahesh23_s: mala',
#  '9/6/18, 12:06 - @mahesh23_s: ani dual sim card ahe na phonr',
#  '9/6/18, 12:06 - @mahesh23_s: ki single sim',
#  '9/6/18, 12:06 - @mahesh23_s: ?',
#  '9/6/18, 12:06 - Sachin Sonavane: Ok',
#  '9/6/18, 12:06 - Sachin Sonavane: Dual sim',
#  '9/6/18, 12:17 - @mahesh23_s: bar',
#  '9/6/18, 12:17 - @mahesh23_s: keep that number with u always',
#  "9/6/18, 12:17 - @mahesh23_s: don't keep in home",
#  '9/6/18, 12:17 - Sachin Sonavane: Ok',
#  '9/6/18, 12:17 - @mahesh23_s: aaila msg read karta yeil ka ?',
#  '9/6/18, 12:18 - @mahesh23_s: ti pathav shakte ka otp',
#  '9/6/18, 12:18 - @mahesh23_s: ?',
#  "9/6/18, 12:18 - Sachin Sonavane: What's app video call karto",
#  '9/6/18, 12:19 - Sachin Sonavane: Ani msg read karto',
#  '9/6/18, 12:19 - Sachin Sonavane: Tu',
#  '9/6/18, 12:19 - Sachin Sonavane: Kar',
#  '9/6/18, 12:19 - Sachin Sonavane: Mi aai la call karto',
#  '9/6/18, 12:19 - @mahesh23_s: nako',
#  '9/6/18, 12:19 - @mahesh23_s: jaaude',
#  '9/6/18, 12:19 - @mahesh23_s: sod',
#  '9/6/18, 12:19 - @mahesh23_s: yevadha urgent nahi',
#  '9/6/18, 12:19 - Sachin Sonavane: Bg tr',
#  '9/6/18, 12:19 - @mahesh23_s: kamavarti',
#  '9/6/18, 12:19 - @mahesh23_s: laksha de',
#  '9/6/18, 12:19 - @mahesh23_s: nanter bagu',
#  '9/6/18, 12:19 - @mahesh23_s: sandhyakali',
#  '9/6/18, 12:19 - @mahesh23_s: gym varun alyavarti',
#  '9/6/18, 12:20 - Sachin Sonavane: Chalel',
#  '9/6/18, 20:41 - Sachin Sonavane: Otp',
#  '9/6/18, 20:48 - @mahesh23_s: baher ahe',
#  '9/6/18, 20:48 - @mahesh23_s: karto',
#  '9/6/18, 20:48 - @mahesh23_s: call',
#  '9/6/18, 20:48 - @mahesh23_s: sim replace karun',
#  '9/6/18, 20:48 - @mahesh23_s: tujha mobile madhe',
#  '9/6/18, 20:48 - @mahesh23_s: thev',
#  '9/6/18, 20:51 - Sachin Sonavane: Ho kela',
#  '9/7/18, 10:18 - @mahesh23_s: hi sachin',
#  '9/7/18, 10:21 - Sachin Sonavane: hi',
#  '9/7/18, 10:21 - @mahesh23_s: busy ahe ka',
#  '9/7/18, 10:21 - @mahesh23_s: ?',
#  '9/7/18, 10:21 - @mahesh23_s: ticket book karayach ahe',
#  '9/7/18, 10:22 - Sachin Sonavane: No',
#  '9/7/18, 10:22 - Sachin Sonavane: Sang',
#  '9/7/18, 10:22 - @mahesh23_s: ok',
#  '9/7/18, 10:22 - @mahesh23_s: zoom',
#  '9/7/18, 10:22 - @mahesh23_s: ?',
#  '9/7/18, 10:22 - Sachin Sonavane: No',
#  '9/7/18, 10:22 - Sachin Sonavane: Only msg',
#  '9/7/18, 10:23 - @mahesh23_s: ok',
#  '9/7/18, 10:23 - Sachin Sonavane: Office made ahe',
#  '9/7/18, 10:23 - @mahesh23_s: top  yeil',
#  '9/7/18, 10:23 - @mahesh23_s: msg kar mag',
#  '9/7/18, 10:23 - Sachin Sonavane: Ok',
#  '9/7/18, 10:23 - Sachin Sonavane: Aai la zoom on karayla lavto',
#  '9/7/18, 10:23 - @mahesh23_s: nak9',
#  '9/7/18, 10:23 - @mahesh23_s: nako',
#  '9/7/18, 10:23 - @mahesh23_s: aatach',
#  '9/7/18, 10:23 - @mahesh23_s: uthlo',
#  '9/7/18, 10:24 - Sachin Sonavane: Ok',
#  '9/7/18, 12:04 - @mahesh23_s: hi',
#  '9/7/18, 12:04 - @mahesh23_s: otp',
#  '9/7/18, 12:04 - @mahesh23_s: yeil bag',
#  '9/7/18, 12:04 - Sachin Sonavane: Ok',
#  '9/7/18, 12:09 - @mahesh23_s: ala ka',
#  '9/7/18, 12:09 - @mahesh23_s: ?',
#  '9/7/18, 12:09 - Sachin Sonavane: Nhi',
#  '9/7/18, 12:20 - @mahesh23_s: hi',
#  '9/7/18, 12:21 - @mahesh23_s: mobile on ahe na',
#  '9/7/18, 12:21 - @mahesh23_s: ?',
#  '9/7/18, 12:21 - Sachin Sonavane: 891140',
#  '9/7/18, 12:22 - @mahesh23_s: parat',
#  '9/7/18, 12:22 - @mahesh23_s: yeil',
#  '9/7/18, 12:22 - Sachin Sonavane: Ok',
#  '9/7/18, 12:22 - @mahesh23_s: ok',
#  '9/7/18, 12:22 - @mahesh23_s: ala ka',
#  '9/7/18, 12:22 - @mahesh23_s: ?',
#  '9/7/18, 12:23 - @mahesh23_s: parat ekda',
#  '9/7/18, 12:23 - Sachin Sonavane: Nhi',
#  '9/7/18, 12:23 - @mahesh23_s: yeil',
#  '9/7/18, 12:23 - @mahesh23_s: ala ka',
#  '9/7/18, 12:23 - @mahesh23_s: ?',
#  '9/7/18, 12:23 - Sachin Sonavane: Nhi',
#  '9/7/18, 12:23 - @mahesh23_s: ok',
#  '9/7/18, 12:23 - @mahesh23_s: yeil',
#  '9/7/18, 12:24 - Sachin Sonavane: Ha',
#  '9/7/18, 12:24 - Sachin Sonavane: Ala ki msg karto',
#  '9/7/18, 12:24 - Sachin Sonavane: ☺',
#  '9/7/18, 12:24 - @mahesh23_s: ok',
#  '9/7/18, 12:24 - @mahesh23_s: ala ka re',
#  '9/7/18, 12:24 - @mahesh23_s: ?',
#  '9/7/18, 12:25 - @mahesh23_s: vel lagat ahe',
#  '9/7/18, 12:25 - Sachin Sonavane: Nhi',
#  '9/7/18, 12:25 - @mahesh23_s: maaila',
#  '9/7/18, 12:25 - @mahesh23_s: yevadha vel',
#  '9/7/18, 12:26 - @mahesh23_s: ala',
#  '9/7/18, 12:26 - @mahesh23_s: ka',
#  '9/7/18, 12:26 - @mahesh23_s: ?',
#  '9/7/18, 12:26 - Sachin Sonavane: Nhi',
#  '9/7/18, 12:31 - Sachin Sonavane: Thod vel thamb',
#  '9/7/18, 12:31 - Sachin Sonavane: Atta mi baher',
#  '9/7/18, 12:31 - Sachin Sonavane: Jatoy',
#  '9/7/18, 12:31 - @mahesh23_s: ok',
#  '9/7/18, 12:34 - @mahesh23_s: yeil bag',
#  '9/7/18, 12:35 - @mahesh23_s: ala ka',
#  '9/7/18, 12:35 - @mahesh23_s: ?',
#  '9/7/18, 12:36 - @mahesh23_s: kay jal re',
#  '9/7/18, 12:36 - @mahesh23_s: ?',
#  '9/7/18, 12:41 - Sachin Sonavane: 643909',
#  '9/7/18, 12:42 - Sachin Sonavane: Bike var hoto',
#  '9/7/18, 12:43 - @mahesh23_s: bar jala',
#  '9/7/18, 12:43 - @mahesh23_s: bike var hota',
#  '9/7/18, 12:43 - @mahesh23_s: nahitar chukicha ticket book kelo asto',
#  '9/7/18, 12:43 - @mahesh23_s: lol',
#  '9/7/18, 12:43 - Sachin Sonavane: Ho',
#  '9/7/18, 12:56 - @mahesh23_s: hi',
#  '9/7/18, 12:56 - @mahesh23_s: otp',
#  '9/7/18, 12:56 - @mahesh23_s: yeil bag',
#  '9/7/18, 12:56 - @mahesh23_s: aata',
#  '9/7/18, 12:59 - @mahesh23_s: ala',
#  '9/7/18, 12:59 - @mahesh23_s: ka',
#  '9/7/18, 12:59 - @mahesh23_s: otp',
#  '9/7/18, 13:00 - @mahesh23_s: lakar  sanga',
#  '9/7/18, 13:00 - Sachin Sonavane: 605390',
#  '9/7/18, 13:00 - @mahesh23_s: jala',
#  '9/7/18, 13:00 - @mahesh23_s: book tickets',
#  '9/7/18, 13:00 - @mahesh23_s: 😍',
#  '9/7/18, 13:01 - Sachin Sonavane: ☺',
#  '9/7/18, 13:02 - Sachin Sonavane: Date??',
#  '9/7/18, 13:03 - @mahesh23_s: <Media omitted>',
#  '9/7/18, 13:45 - @mahesh23_s: aaila sangu nako',
#  '9/7/18, 13:45 - @mahesh23_s: 🤪🤪',
#  '9/7/18, 13:46 - Sachin Sonavane: Ha',
#  '9/7/18, 13:47 - @mahesh23_s: tata',
#  '9/7/18, 13:47 - @mahesh23_s: cha kay',
#  '9/7/18, 13:47 - @mahesh23_s: jala',
#  '9/7/18, 13:47 - @mahesh23_s: ?',
#  '9/7/18, 13:47 - Sachin Sonavane: Ajun nhi',
#  '9/7/18, 13:47 - Sachin Sonavane: Arrange karnar ahe',
#  '9/7/18, 13:47 - @mahesh23_s: ok',
#  '9/7/18, 13:47 - @mahesh23_s: fine',
#  '9/7/18, 13:48 - @mahesh23_s: ani kamat loka chan ahet',
#  '9/7/18, 13:48 - @mahesh23_s: na ?',
#  '9/7/18, 13:48 - @mahesh23_s: aata jithe kam karto tithe',
#  '9/7/18, 13:48 - Sachin Sonavane: Ho',
#  '9/7/18, 13:48 - @mahesh23_s: ok',
#  '9/7/18, 13:48 - Sachin Sonavane: Chan',
#  '9/7/18, 15:57 - Sachin Sonavane: 919 rs for 3 days payment',
#  '9/7/18, 15:59 - Sachin Sonavane: <Media omitted>',
#  '9/7/18, 16:03 - Sachin Sonavane: <Media omitted>',
#  '9/7/18, 16:03 - Sachin Sonavane: <Media omitted>',
#  '9/7/18, 16:03 - Sachin Sonavane: <Media omitted>',
#  '9/7/18, 16:03 - Sachin Sonavane: <Media omitted>',
#  '9/7/18, 16:03 - Sachin Sonavane: 1yr completed',
#  '9/7/18, 16:23 - @mahesh23_s: wow',
#  '9/7/18, 16:23 - @mahesh23_s: sachin sonawane',
#  '9/7/18, 16:23 - @mahesh23_s: w cha v',
#  '9/7/18, 16:23 - @mahesh23_s: karayala sang',
#  '9/7/18, 16:23 - Sachin Sonavane: Ho',
#  '9/7/18, 16:23 - Sachin Sonavane: Atta te sir nhiy',
#  '9/7/18, 16:24 - @mahesh23_s: proud of you 😍',
#  '9/7/18, 16:24 - Sachin Sonavane: 😄',
#  '9/7/18, 16:24 - Sachin Sonavane: Only 919',
#  '9/7/18, 16:25 - @mahesh23_s: no problem',
#  '9/7/18, 16:25 - @mahesh23_s: money is not imo',
#  '9/7/18, 16:25 - @mahesh23_s: imp',
#  '9/7/18, 16:25 - Sachin Sonavane: Hm',
#  '9/7/18, 16:25 - Sachin Sonavane: Ok',
#  '9/7/18, 16:26 - @mahesh23_s: 😍',
#  '9/7/18, 16:26 - @mahesh23_s: aaila khayala gheun ja',
#  '9/7/18, 16:26 - @mahesh23_s: kahitari',
#  '9/7/18, 16:26 - Sachin Sonavane: <Media omitted>',
#  '9/7/18, 16:27 - @mahesh23_s: 👌🏻',
#  '9/7/18, 16:27 - Sachin Sonavane: Ho',
#  '9/7/18, 16:27 - Sachin Sonavane: <Media omitted>',
#  '9/7/18, 16:27 - Sachin Sonavane: Ekatach ahe office made',
#  '9/7/18, 16:27 - Sachin Sonavane: Basloy',
#  '9/7/18, 16:28 - @mahesh23_s: ka',
#  '9/7/18, 16:28 - @mahesh23_s: ?',
#  '9/7/18, 16:28 - @mahesh23_s: baki log kothe',
#  '9/7/18, 16:28 - Sachin Sonavane: Gelyat tyanch tyanch kam karayla',
#  '9/7/18, 16:29 - Sachin Sonavane: Mi new ahe so mala lamb patavat nhi chote chote Kam detat',
#  '9/7/18, 16:29 - Sachin Sonavane: Near distance vale',
#  '9/7/18, 16:29 - @mahesh23_s: ok.. samjhala',
#  '9/7/18, 16:29 - @mahesh23_s: kara kam',
#  '9/7/18, 16:29 - @mahesh23_s: 😍',
#  '9/7/18, 16:29 - @mahesh23_s: mi chicken banavat ahe',
#  '9/7/18, 16:29 - @mahesh23_s: tata madhe pan bag ekda',
#  '9/7/18, 16:29 - Sachin Sonavane: Ho',
#  '9/7/18, 16:29 - Sachin Sonavane: Ok',
#  '9/7/18, 17:28 - @mahesh23_s: tujha resume pathav bagu',
#  '9/7/18, 17:28 - @mahesh23_s: mala',
#  '9/7/18, 17:28 - @mahesh23_s: ekda',
#  '9/7/18, 17:28 - @mahesh23_s: naukri.com',
#  '9/7/18, 17:28 - @mahesh23_s: che login details pan',
#  '9/7/18, 17:29 - Sachin Sonavane: Nantr',
#  '9/7/18, 17:29 - Sachin Sonavane: Atta baher jatoy',
#  '9/7/18, 17:29 - @mahesh23_s: bar',
#  '9/7/18, 17:29 - Sachin Sonavane: This message was deleted',
#  '9/9/18, 17:32 - @mahesh23_s: hi',
#  '9/9/18, 17:32 - @mahesh23_s: sachin',
#  '9/9/18, 17:32 - @mahesh23_s: bhanu ala hota ka ghari?',
#  '9/9/18, 17:32 - Sachin Sonavane: Ho',
#  '9/9/18, 17:32 - @mahesh23_s: kay bolala',
#  '9/9/18, 17:32 - @mahesh23_s: ?',
#  '9/9/18, 17:32 - Sachin Sonavane: Nko Karu mhan mala job tasl',
#  '9/9/18, 17:33 - Sachin Sonavane: Tusion lav mhan',
#  '9/9/18, 17:33 - @mahesh23_s: ok',
#  '9/9/18, 17:33 - @mahesh23_s: tech bolat hoto mi tula',
#  '9/9/18, 17:33 - Sachin Sonavane: Banking kar mhanla',
#  '9/9/18, 17:33 - @mahesh23_s: yes',
#  '9/9/18, 17:33 - @mahesh23_s: ek serious gheun kar',
#  '9/9/18, 17:33 - @mahesh23_s: don nahi jamnaar',
#  '9/9/18, 17:33 - @mahesh23_s: tution lava',
#  '9/9/18, 17:36 - @mahesh23_s: baguya',
#  '9/9/18, 17:36 - @mahesh23_s: diwali la yeto ahe mi',
#  '9/9/18, 17:36 - @mahesh23_s: tevha bolu',
#  '9/9/18, 17:36 - @mahesh23_s: to paryant',
#  '9/9/18, 17:36 - @mahesh23_s: abyass chalu thev',
#  '9/9/18, 17:36 - @mahesh23_s: banking result',
#  '9/9/18, 17:36 - @mahesh23_s: ?',
#  '9/9/18, 17:36 - Sachin Sonavane: Po nhi zal',
#  '9/9/18, 17:36 - @mahesh23_s: ok',
#  '9/9/18, 17:36 - Sachin Sonavane: Clerk result yaych ahe',
#  '9/9/18, 17:37 - @mahesh23_s: aaj yenaar hota na',
#  '9/9/18, 17:37 - @mahesh23_s: ?',
#  '9/9/18, 17:37 - Sachin Sonavane: Nhi may be Monday Tuesday',
#  '9/9/18, 17:37 - @mahesh23_s: ok',
#  '9/9/18, 23:18 - @mahesh23_s: 1. Explore CDAC courses in pune',
#  '9/9/18, 23:18 - @mahesh23_s: 2. Explore BANK tuition classes',
#  '9/9/18, 23:19 - @mahesh23_s: 3.Explore CCNA classes in pune',
#  '9/9/18, 23:19 - @mahesh23_s: fees - > Course Sturcture ->',
#  '9/9/18, 23:19 - @mahesh23_s: EXTC -> IT migration',
#  '9/9/18, 23:19 - @mahesh23_s: Campus placements',
#  '9/9/18, 23:19 - @mahesh23_s: Tenure',
#  '9/9/18, 23:19 - @mahesh23_s: kiti varshacha course',
#  '9/9/18, 23:19 - @mahesh23_s: ahe',
#  "9/9/18, 23:28 - @mahesh23_s: Admissions to all PG Diploma courses of C-DAC are done through C-DAC's computerized Common Admission Test (C-CAT). Every year, C-CAT is usually conducted in June (for August admissions) and December (for February admissions).",
#  '9/9/18, 23:28 - @mahesh23_s: https://www.cdac.in/index.aspx?id=edu_acts_PGDiplomaAdmission#',
#  '9/9/18, 23:44 - @mahesh23_s: pls dont take tension',
#  '9/9/18, 23:44 - @mahesh23_s: and dont worry',
#  '9/9/18, 23:44 - @mahesh23_s: u r already doing best',
#  '9/9/18, 23:44 - @mahesh23_s: only thing is proper guidance is not there',
#  '9/9/18, 23:45 - Sachin Sonavane: ☺',
#  '9/9/18, 23:45 - @mahesh23_s: i am not able to give you more time',
#  '9/9/18, 23:45 - @mahesh23_s: pls undertsand me',
#  '9/9/18, 23:45 - @mahesh23_s: i will do something',
#  '9/9/18, 23:45 - Sachin Sonavane: H',
#  '9/9/18, 23:45 - @mahesh23_s: u keep working hard',
#  '9/9/18, 23:45 - Sachin Sonavane: 👍🏻',
#  '9/9/18, 23:57 - Sachin Sonavane: ATM ₹240  balance ka jatoy',
#  '9/9/18, 23:57 - Sachin Sonavane: Sbi ch online login karun bagav lagel',
#  '9/9/18, 23:58 - Sachin Sonavane: Call Karun pahu ka',
#  '9/9/18, 23:59 - @mahesh23_s: bag',
#  '9/10/18, 10:23 - Sachin Sonavane: HDFC life one click',
#  '9/10/18, 10:23 - Sachin Sonavane: Sathi call alel',
#  '9/10/18, 10:23 - Sachin Sonavane: Tumchya kade time asel tr discuss karu mhanale',
#  '9/10/18, 10:24 - Sachin Sonavane: Time nhi mhanlalo sadya 4pm la call kara   mhanalo',
#  '9/10/18, 10:26 - @mahesh23_s: ok',
#  '9/10/18, 10:26 - @mahesh23_s: np',
#  '9/10/18, 10:27 - Sachin Sonavane: Tyanch call al tr Kay bolu',
#  '9/10/18, 10:35 - @mahesh23_s: nit interested',
#  '9/10/18, 10:36 - Sachin Sonavane: Ok',
#  '9/10/18, 11:19 - @mahesh23_s: Hi Mahi, gm',
#  'I have told Sachin to go for coaching for banks and UPSC simultaneously everyday and study hard. As he has some exams in October and November. This already late. So let him join in any institute ASAP. System and desktop support is waste job... A frustration later. So if he goes for coaching he will get confidence that he can crack any online exam',
#  '9/10/18, 11:19 - @mahesh23_s: ek kam kar job sodun de .. ani classes explore kar',
#  '9/10/18, 11:19 - @mahesh23_s: jau nako kamala',
#  '9/10/18, 11:20 - Sachin Sonavane: Aaj job la aloy',
#  '9/10/18, 11:20 - @mahesh23_s: Oct and nov madhe exam',
#  '9/10/18, 11:20 - @mahesh23_s: ahet ?',
#  '9/10/18, 11:20 - Sachin Sonavane: Ho ahet',
#  '9/10/18, 11:21 - @mahesh23_s: kar prep',
#  '9/10/18, 11:21 - @mahesh23_s: tyasathi',
#  '9/10/18, 11:21 - @mahesh23_s: ani classes explore kar banking',
#  '9/10/18, 11:21 - Sachin Sonavane: IBPS po and clerk ',
#  'Rbi assistant',
#  'IBPS so',
#  'NIacl assistant',
#  '9/10/18, 11:21 - @mahesh23_s: ok',
#  '9/10/18, 11:21 - @mahesh23_s: explore those',
#  "9/10/18, 11:22 - @mahesh23_s: tell ur boss I won't be able to come as my mom is alone in him and brother wants me to look after her",
#  '9/10/18, 11:22 - @mahesh23_s: nahi tar tula jasa jamta',
#  '9/10/18, 11:22 - @mahesh23_s: tasa sang ani ye',
#  '9/10/18, 11:22 - @mahesh23_s: ghari',
#  '9/10/18, 11:22 - @mahesh23_s: abhyas kar',
#  '9/10/18, 11:22 - @mahesh23_s: vel ahe ajun',
#  '9/10/18, 11:22 - @mahesh23_s: bharpur',
#  '9/10/18, 11:23 - @mahesh23_s: go and visit institute and enquire',
#  '9/10/18, 11:23 - Sachin Sonavane: Atta ek task sangitle ahe excel sheet made to complete karto mg bolto',
#  '9/10/18, 11:24 - @mahesh23_s: ok',
#  '9/10/18, 11:24 - @mahesh23_s: fine',
#  '9/10/18, 11:24 - @mahesh23_s: no problem',
#  '9/10/18, 11:24 - @mahesh23_s: call karu ka ?',
#  '9/10/18, 11:24 - Sachin Sonavane: Nko',
#  '9/10/18, 11:24 - @mahesh23_s: okay..',
#  '9/10/18, 11:24 - Sachin Sonavane: Thodya velen karto',
#  '9/10/18, 11:24 - @mahesh23_s: no problem',
#  '9/10/18, 11:24 - @mahesh23_s: tula avadat nahi na job ?',
#  '9/10/18, 11:24 - @mahesh23_s: toh',
#  '9/10/18, 11:24 - @mahesh23_s: bank exams kar',
#  '9/10/18, 11:35 - @mahesh23_s: resume send',
#  '9/10/18, 11:35 - @mahesh23_s: kar',
#  '9/10/18, 11:35 - @mahesh23_s: mala',
#  '9/10/18, 11:35 - @mahesh23_s: tuja',
#  '9/10/18, 12:04 - @mahesh23_s: https://www.freshersworld.com/',
#  '9/10/18, 12:05 - @mahesh23_s: https://www.elitmus.com/',
#  '9/10/18, 12:22 - Sachin Sonavane: Hi',
#  '9/10/18, 12:22 - Sachin Sonavane: Call karto ka',
#  '9/10/18, 12:23 - Sachin Sonavane: Job sodu na',
#  '9/10/18, 12:23 - @mahesh23_s: ok',
#  '9/10/18, 12:23 - @mahesh23_s: calling u on skype',
#  '9/10/18, 14:49 - Sachin Sonavane: Hi bro aai mhantey ki ek month kar made made sutti ghe study Sathi ek month nantr sod ',
#  'Atta Ganpati pn ahe made sutti hotat',
#  '9/10/18, 17:00 - @mahesh23_s: ratri',
#  '9/10/18, 17:00 - @mahesh23_s: call karto',
#  '9/10/18, 17:00 - Sachin Sonavane: Ok',
#  '9/10/18, 17:04 - Sachin Sonavane: <Media omitted>',
#  '9/10/18, 18:27 - @mahesh23_s: resign job and',
#  '9/10/18, 18:27 - @mahesh23_s: do bank class research',
#  '9/10/18, 18:27 - @mahesh23_s: https://www.cdac.in/index.aspx?id=edu_acts_PGDiplomaAdmission#',
#  '9/10/18, 18:27 - @mahesh23_s: this is pgdm',
#  '9/10/18, 18:27 - @mahesh23_s: post graduate diploma',
#  '9/10/18, 18:28 - @mahesh23_s: entrance exam aste',
#  '9/10/18, 18:28 - @mahesh23_s: man bag',
#  '9/10/18, 18:28 - @mahesh23_s: te pan ekda',
#  '9/10/18, 18:30 - Sachin Sonavane: Sandya Kali bolu',
#  '9/10/18, 18:30 - Sachin Sonavane: Aaj tr job day',
#  '9/10/18, 18:30 - @mahesh23_s: ok',
#  '9/10/18, 18:30 - @mahesh23_s: bagu',
#  '9/10/18, 18:31 - @mahesh23_s: mi karto call',
#  '9/10/18, 18:31 - @mahesh23_s: nanter decide karu',
#  '9/10/18, 18:31 - Sachin Sonavane: Ok',
#  '9/10/18, 20:39 - Sachin Sonavane: Hi',
#  '9/10/18, 21:40 - @mahesh23_s: jevan',
#  '9/10/18, 21:40 - @mahesh23_s: kattoy',
#  '9/10/18, 21:40 - Sachin Sonavane: Ok',
#  '9/10/18, 22:12 - @mahesh23_s: hi',
#  '9/10/18, 22:12 - @mahesh23_s: zoom',
#  '9/10/18, 22:12 - @mahesh23_s: pls join zoom',
#  '9/10/18, 22:33 - Sachin Sonavane: This message was deleted',
#  '9/10/18, 22:34 - @mahesh23_s: translate.google.com',
#  '9/10/18, 22:37 - @mahesh23_s: https://translate.google.com',
#  '9/10/18, 22:38 - Sachin Sonavane: Subject: Interview Call Letter for the post of ‘Clerk’',
#  ' ',
#  'Dear Sir/Madam,',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  'With reference to your application for the above post, you are requested to be present for personal interview on 6/6/2018 at 12.00 NOON (Please bring all your original testimonials, Graduation Certificate, Pancard, Aadharcard, School Leaving Certificate, etc.) at below mentioned address:',
#  '',
#  'Abhyudaya Co-op. Bank Ltd.',
#  '',
#  'Abhyudaya Bank Building,',
#  '',
#  'HRM -Department, 2nd Floor,',
#  '',
#  'Sector 17, Vashi, Navi Mumbai.',
#  '',
#  'Tel. No. : 27895090 / 65107394',
#  '',
#  '2. Please note that no travelling or any other expenses are payable for attending the interview.',
#  ' ',
#  '',
#  ' ',
#  '',
#  'HRM DEPT',
#  'ABHYUDAYA CO-OP BANK LTD',
#  '9/10/18, 22:42 - Sachin Sonavane: <Media omitted>',
#  '9/10/18, 22:45 - Sachin Sonavane: https://www.abhyudayabank.co.in/english/home.aspx',
#  '9/11/18, 20:36 - Sachin Sonavane: Aai ch call alel',
#  '9/11/18, 20:37 - @mahesh23_s: ok',
#  '9/11/18, 20:37 - Sachin Sonavane: Bus made he mhan',
#  '9/11/18, 20:37 - @mahesh23_s: kothe geli',
#  '9/11/18, 20:37 - @mahesh23_s: ahe',
#  '9/11/18, 20:37 - @mahesh23_s: ?',
#  '9/11/18, 20:37 - Sachin Sonavane: Hadapsar la geleli asacb',
#  '9/11/18, 20:37 - @mahesh23_s: ok',
#  '9/11/18, 20:37 - Sachin Sonavane: Alyavar v4to',
#  '9/11/18, 20:37 - @mahesh23_s: ok',
#  '9/11/18, 20:37 - @mahesh23_s: chal mag bye',
#  '9/11/18, 20:37 - Sachin Sonavane: Hm',
#  '9/12/18, 16:04 - @mahesh23_s: hisachin',
#  '9/12/18, 16:04 - @mahesh23_s: busy ahe ka?',
#  '9/12/18, 16:05 - @mahesh23_s: hdfc password reset karayach ahe',
#  '9/12/18, 16:05 - @mahesh23_s: emergency nahi',
#  '9/12/18, 16:05 - @mahesh23_s: nanater pan karu shakto',
#  '9/12/18, 16:05 - @mahesh23_s: ping kar once free',
#  '9/12/18, 16:06 - Sachin Sonavane: Hi',
#  '9/12/18, 16:07 - @mahesh23_s: otp',
#  '9/12/18, 16:07 - @mahesh23_s: yeil',
#  '9/12/18, 16:07 - @mahesh23_s: sangto ka',
#  '9/12/18, 16:09 - @mahesh23_s: ala ka',
#  '9/12/18, 16:09 - @mahesh23_s: ?',
#  '9/12/18, 16:09 - @mahesh23_s: otp',
#  '9/12/18, 16:09 - @mahesh23_s: ?',
#  '9/12/18, 16:12 - Sachin Sonavane: 574',
#  '9/12/18, 16:13 - @mahesh23_s: thnaks',
#  '9/12/18, 16:13 - @mahesh23_s: parat ala ka',
#  '9/12/18, 16:13 - @mahesh23_s: otp',
#  '9/12/18, 16:13 - @mahesh23_s: ?',
#  '9/12/18, 16:14 - Sachin Sonavane: 687315',
#  '9/12/18, 16:15 - @mahesh23_s: thanks',
#  '9/12/18, 16:15 - Sachin Sonavane: ☺👍🏻',
#  '9/12/18, 16:16 - Sachin Sonavane: Zal ka change',
#  '9/12/18, 16:17 - @mahesh23_s: yes',
#  '9/12/18, 16:17 - @mahesh23_s: swapnil',
#  '9/12/18, 16:18 - @mahesh23_s: call karel tula',
#  '9/12/18, 16:18 - @mahesh23_s: class baddal',
#  '9/12/18, 16:18 - @mahesh23_s: bag kay manto te',
#  '9/12/18, 16:18 - @mahesh23_s: ratri',
#  '9/12/18, 16:18 - @mahesh23_s: ankhi tu pan explore kar classes',
#  '9/12/18, 16:31 - Sachin Sonavane: Ok',
#  '9/12/18, 16:31 - Sachin Sonavane: Your a/c no. XXXXXXXX6822 is debited for Rs.50000.00 on 12-09-18 and a/c of SONAVANE M MANIK has been credited (IMPS Ref no 825516877574).',
#  '9/12/18, 16:37 - @mahesh23_s: yes',
#  '9/12/18, 16:37 - @mahesh23_s: ratri',
#  '9/12/18, 16:37 - @mahesh23_s: call karto',
#  '9/12/18, 16:57 - Sachin Sonavane: Congratulations! Your IPIN has been successfully reset',
#  '9/12/18, 17:40 - @mahesh23_s: ok',
#  '9/12/18, 22:48 - @mahesh23_s: hi',
#  '9/12/18, 22:48 - @mahesh23_s: sachin',
#  '9/12/18, 22:48 - @mahesh23_s: jopla ahes ?',
#  '9/12/18, 22:48 - @mahesh23_s: ki jaga ahe',
#  '9/12/18, 22:48 - @mahesh23_s: ?',
#  '9/12/18, 22:50 - @mahesh23_s: https://zoom.us/j/9892821748',
#  '9/12/18, 22:55 - Sachin Sonavane: <Media omitted>',
#  '9/12/18, 22:55 - Sachin Sonavane: <Media omitted>',
#  '9/12/18, 23:03 - @mahesh23_s: nice',
#  '9/12/18, 23:07 - @mahesh23_s: nice',
#  '9/13/18, 13:49 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:49 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:50 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:50 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:50 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:50 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:50 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:50 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:50 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:50 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:50 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:50 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 13:50 - Sachin Sonavane: <Media omitted>',
#  '9/13/18, 15:20 - @mahesh23_s: wow',
#  '9/13/18, 15:20 - @mahesh23_s: nice',
#  '9/13/18, 15:20 - @mahesh23_s: yar',
#  '9/13/18, 15:20 - @mahesh23_s: mi aata uthlo',
#  '9/13/18, 15:20 - @mahesh23_s: 😂😂',
#  '9/13/18, 15:20 - @mahesh23_s: aaj sutti ahe mala',
#  '9/13/18, 17:14 - Sachin Sonavane: Hm',
#  '9/14/18, 17:07 - @mahesh23_s: hi',
#  '9/14/18, 17:07 - @mahesh23_s: sachin',
#  '9/14/18, 17:07 - @mahesh23_s: office madhe ahe ka ?',
#  '9/14/18, 17:07 - Sachin Sonavane: Bol',
#  '9/14/18, 17:07 - @mahesh23_s: kahi',
#  '9/14/18, 17:07 - @mahesh23_s: nahi asach',
#  '9/14/18, 17:07 - Sachin Sonavane: Ok',
#  '9/14/18, 17:08 - Sachin Sonavane: The Forum Bldg, 5th floor, Above Ranka Jewellers, Pune - Satara Rd, Padmadarshan Society, Sant Nagar, Padmavati Nagar, Pune, Maharashtra 411009',
#  '9/14/18, 17:08 - Sachin Sonavane: Aapti academy',
#  '9/14/18, 17:08 - @mahesh23_s: ok',
#  '9/14/18, 17:08 - Sachin Sonavane: Banking',
#  '9/14/18, 17:08 - @mahesh23_s: accha',
#  '9/14/18, 17:08 - @mahesh23_s: good',
#  '9/14/18, 17:09 - @mahesh23_s: chan ahe man ka',
#  '9/14/18, 17:09 - Sachin Sonavane: Demo class la bas mhanala',
#  '9/14/18, 17:09 - @mahesh23_s: gandhi class',
#  '9/14/18, 17:09 - @mahesh23_s: ?',
#  '9/14/18, 17:09 - @mahesh23_s: call karu ka',
#  '9/14/18, 17:09 - @mahesh23_s: ?',
#  '9/14/18, 17:09 - Sachin Sonavane: Kar',
#  '9/14/18, 17:10 - @mahesh23_s: zoom',
#  '9/14/18, 17:11 - @mahesh23_s: audio join kar',
#  '9/14/18, 17:11 - @mahesh23_s: zoom',
#  '9/14/18, 17:11 - Sachin Sonavane: SBI po 3time clear kelay',
#  '9/14/18, 17:11 - Sachin Sonavane: Demo class basun nantr decide kar mhanala',
#  '9/14/18, 17:12 - Sachin Sonavane: Fees 10000+ Gst',
#  '9/14/18, 17:12 - Sachin Sonavane: Jar one time det asel tr 10000',
#  '9/14/18, 17:12 - Sachin Sonavane: Without gst',
#  '9/14/18, 17:13 - @mahesh23_s: ok',
#  '9/14/18, 17:13 - @mahesh23_s: samjhala',
#  '9/14/18, 17:13 - @mahesh23_s: zoom',
#  '9/14/18, 17:13 - @mahesh23_s: ?',
#  '9/14/18, 17:13 - Sachin Sonavane: Bakich nantr sangto',
#  '9/14/18, 17:13 - Sachin Sonavane: I mean',
#  '9/14/18, 17:13 - Sachin Sonavane: Call var',
#  '9/14/18, 17:18 - @mahesh23_s: ok',
#  '9/15/18, 21:28 - @mahesh23_s: hi',
#  ...]

# %%
 #Remove new lines
chat = [line.strip() for line in chat]
print("length of chat is:")
print(len(chat))
# Out:
# length of chat is:
# 9946

# %%
#Clean out the join notification lines
clean_chat = [line for line in chat if not "joined using this" in line]

#Further cleaning
#Remove empty lines
clean_chat = [line for line in clean_chat if len(line) > 1]
print("length of clean_chat is:")
print(len(clean_chat))
# Out:
# length of clean_chat is:
# 9706

# %%
left = [line for line in clean_chat if line.endswith("left")]
left
# Out:
# ['8. Turn left']

# %%
#Clean out the left notification lines
clean_chat = [line for line in clean_chat if not line.endswith("left")]
print(len(clean_chat))
# Out:
# 9705

# %%
#Merge messages that belong together
msgs = [] #message container
pos = 0 #counter for position of msgs in the container
"""
Flow:
For every line, see if it matches the expression which is starting with the format "number(s)+slash" eg "12/"
If it does, it is a new line of conversion as they begin with dates, add it to msgs container
Else, it is a continuation of the previous line, add it to the previous line and append to msgs, then pop previous line.
"""
for line in clean_chat:
    if re.findall("\A\d+[/]", line):
        msgs.append(line)
        pos += 1
    else:
        take = msgs[pos-1] + ". " + line
        msgs.append(take)
        msgs.pop(pos-1)

# %%
time = [msgs[i].split(',')[1].split('-')[0] for i in range(len(msgs))]
time = [s.strip(' ') for s in time] # Remove spacing
time
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-bfe87fad953a> in <module>
# ----> 1 time = [msgs[i].split(',')[1].split('-')[0] for i in range(len(msgs))]
#       2 time = [s.strip(' ') for s in time] # Remove spacing
#       3 time
#
# <ipython-input-68-bfe87fad953a> in <listcomp>(.0)
# ----> 1 time = [msgs[i].split(',')[1].split('-')[0] for i in range(len(msgs))]
#       2 time = [s.strip(' ') for s in time] # Remove spacing
#       3 time
#
# IndexError: list index out of range

# %%
msgs[i].split('-')[1].split(':')[0]
# Out:
# ' @mahesh23_s'

# %%
date = [msgs[i].split(',')[0] for i in range(len(msgs))]
len(date) 

name = [msgs[i].split('-')[1].split(':')[0] for i in range(len(msgs))]
len(name) 

content = []
for i in range(len(msgs)):
    try:
        content.append(msgs[i].split(':')[2])
    except IndexError:
        content.append('Missing Text')
len(content)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-80-1a5ae68b8f03> in <module>
# ----> 1 name = [msgs[i].split('-')[1].split(':')[0] for i in range(len(msgs))]
#       2 len(name)
#       3
#
# <ipython-input-80-1a5ae68b8f03> in <listcomp>(.0)
# ----> 1 name = [msgs[i].split('-')[1].split(':')[0] for i in range(len(msgs))]
#       2 len(name)
#       3
#
# IndexError: list index out of range

# %%
msgs[500].split('-')[1].split(':')[0]
# Out:
# ' @mahesh23_s'

# %%
df = pd.DataFrame(list(zip(date, time, name, content)), columns = ['Date', 'Time', 'Name', 'Content'])

# %%
df = df[df["Content"]!='Missing Text']
df.reset_index(inplace=True, drop=True)
df
# Out:
#         Date   Time               Name  \
# 0    5/16/20  14:41   +971 52 766 2655
# 1    5/16/20  14:41    +91 97914 49719
# 2    5/16/20  14:42    +91 97914 49719
# 3    5/16/20  14:43    +91 97914 49719
# 4    5/16/20  14:43   +971 52 766 2655
# ..       ...    ...                ...
# 208  5/29/20  15:53    +91 88852 33238
# 209  5/29/20  16:27    +91 97914 49719
# 210  5/29/20  16:28    +91 88852 33238
# 211  5/29/20  16:29    +91 82973 34445
# 212  5/29/20  16:54    +91 88852 33238
#
#                                                Content
# 0     Thanks for adding me the group @919791449719....
# 1           Follow this link to join my WhatsApp group
# 2                                    You are welcome👍🏻
# 3     If you want to add any of your friends kindly...
# 4                                               Surely
# ..                                                 ...
# 208   Requirement is not to change to field data ty...
# 209   Are you opening the exported file in excel or...
# 210                                Its exported as csv
# 211   Can you please share the test data here then ...
# 212                                    <Media omitted>
#
# [213 rows x 4 columns]

# %%
df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])
df['DateTime']
# Out:
# <ipython-input-17-23903c38c930>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])
# 0     2020-05-16 14:41:00
# 1     2020-05-16 14:41:00
# 2     2020-05-16 14:42:00
# 3     2020-05-16 14:43:00
# 4     2020-05-16 14:43:00
#               ...
# 208   2020-05-29 15:53:00
# 209   2020-05-29 16:27:00
# 210   2020-05-29 16:28:00
# 211   2020-05-29 16:29:00
# 212   2020-05-29 16:54:00
# Name: DateTime, Length: 213, dtype: datetime64[ns]

# %%
df['weekday'] = df['DateTime'].apply(lambda x: x.day_name())
# Out:
# <ipython-input-18-4a8d52198f1a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weekday'] = df['DateTime'].apply(lambda x: x.day_name())

# %%
df['Letter_Count'] = df['Content'].apply(lambda s : len(s))
df['Word_Count'] = df['Content'].apply(lambda s : len(s.split(' ')))
# Out:
# <ipython-input-19-ab3fc57b1f16>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Letter_Count'] = df['Content'].apply(lambda s : len(s))
# <ipython-input-19-ab3fc57b1f16>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Word_Count'] = df['Content'].apply(lambda s : len(s.split(' ')))

# %%
df['Hour'] = df['Time'].apply(lambda x : x.split(':')[0]) 
# The first token of a value in the Time Column contains the hour (Eg., "12" in "12:15")
# Out:
# <ipython-input-20-e0d37b0fb32e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hour'] = df['Time'].apply(lambda x : x.split(':')[0])

# %%
#print first five rows of our dataframe
df.head()
# Out:
#       Date   Time               Name  \
# 0  5/16/20  14:41   +971 52 766 2655
# 1  5/16/20  14:41    +91 97914 49719
# 2  5/16/20  14:42    +91 97914 49719
# 3  5/16/20  14:43    +91 97914 49719
# 4  5/16/20  14:43   +971 52 766 2655
#
#                                              Content            DateTime  \
# 0   Thanks for adding me the group @919791449719.... 2020-05-16 14:41:00
# 1         Follow this link to join my WhatsApp group 2020-05-16 14:41:00
# 2                                  You are welcome👍🏻 2020-05-16 14:42:00
# 3   If you want to add any of your friends kindly... 2020-05-16 14:43:00
# 4                                             Surely 2020-05-16 14:43:00
#
#     weekday  Letter_Count  Word_Count Hour
# 0  Saturday            70          12   14
# 1  Saturday            43           9   14
# 2  Saturday            18           4   14
# 3  Saturday            75          16   14
# 4  Saturday             7           2   14

# %%
fileName = "Power BI Developers.txt"
fileName
# Out:
# 'Power BI Developers.txt'

# %%
filePath = 'C:\\Users\\msonavane\\Downloads\whatsapp\Power BI Developers.txt'
# Out:
#   File "<ipython-input-23-7c32e38078d2>", line 1
#     filePath = 'C:\Users\msonavane\Downloads\whatsapp\Power BI Developers.txt'
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import os
path= os.getcwd()
path
# Out:
# 'C:\\Users\\msonavane\\Downloads\\whatsapp'

# %%
print(os.path)
# Out:
# <module 'ntpath' from 'c:\\users\\msonavane\\appdata\\local\\programs\\python\\python38\\lib\\ntpath.py'>

# %%
print(os.path.join(path,"file.txt"))
# Out:
# C:\Users\msonavane\Downloads\whatsapp\file.txt

# %%
filename = "abc.txt"

# %%
filename.split('.')[0]+'.csv'
# Out:
# 'abc.csv'
